# %%
import pandas as pd

file_name = 'sample.xlsx'


def ColRename(df):
    new_name = df.iloc[0]
    for i,name in enumerate(new_name):
        df.rename(columns = {i : name}, inplace = True)
    mall_1.set_axis(new_name, axis='columns', copy=False)
    print(df.head())
    return df    
        
df = pd.read_excel(file_name, sheet_name=['쇼핑몰1주문내역','쇼핑몰2주문내역'])

mall_1 = df['쇼핑몰1주문내역']
mall_2 = df['쇼핑몰2주문내역']

# print(mall_1)
# Out:
# 0                                   주문아이디                     상품아이디  \
# 0                                   주문아이디                     상품아이디
# 1    98c85621-c99c-4807-9f02-10c9f789b97c  6399c5a22850173bbbbf8aa5
# 2    7997d8a2-7f04-4f60-ab15-cd948bf6b0ac  6385a1eefa20ca06a23bddf1
# 3    24ea04de-8351-4062-8d8f-4ad9084cb8fa  6399d6e4913bb83085510c20
# 4    3b5afefe-caf4-4918-a459-3207fa4353d3  63b81bd9099efc0d70b571fb
# ..                                    ...                       ...
# 239  a6838a45-b133-4434-8c51-7403e4fe19b0  639dacffd5bc95f9790d210a
# 240  07e16792-d3f4-419f-99ce-c283673b7571  639dacffd5bc95f9790d210a
# 241  968c83a3-5296-481d-a975-58078690688e  639dacffd5bc95f9790d210a
# 242  1f9d9642-3cf3-4224-89f2-d73e1869df5e  62f65cf7b81b8a32ead996ce
# 243  bb927b6c-b285-4e87-b287-99b165042813  62f65cf7b81b8a32ead996ce
#
# 0                          합배송아이디  판매자 상품코드  \
# 0                          합배송아이디  판매자 상품코드
# 1    230314hvpxGCzBPtPhHvqX6mJQyU       NaN
# ...
